# %%
import sys
sys.path.append('../')

import librosa
import tensorflow as tf
import matplotlib.pyplot as plt


from utils.config_utils import *
from utils.voice.mfcc import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# file_path = r"D:\Advait\Handouts_and_assignments\Raspberry_Pi\whistle_activated_camera\data\voice_data\bed\78622c2b_nohash_0.wav"
file_path = r"D:\Advait\Handouts_and_assignments\Raspberry_Pi\whistle_activated_camera\data\recorded_bg_data\snippets\0.wav"
# file_path = r"D:\Advait\Handouts_and_assignments\Raspberry_Pi\whistle_activated_camera\data\whistle\whistle_5.wav"
y, sr = librosa.load(file_path, sr=read_config()['sound_config']['sr'])
plt.plot(y)
plt.yticks(np.arange(-1.2, 1.2, 0.2))
plt.show()

# %%
m = mfcc(y)

fig, ax = plt.subplots(1,1, figsize=(10,30))
ax.imshow(m)
plt.show()

# %%
m.shape
# Out:
# (12, 126)

# %%
lstm = tf.keras.layers.LSTM(64)

# %%
y = lstm(m[None,:,:].astype(np.float64))
y.shape
# Out:
# TensorShape([1, 64])
